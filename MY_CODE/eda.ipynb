# %% [markdown]
# # Notebook for Exploratory Data Analysis

# %% [markdown]
# ### Function for description of the dataframe

# %%
import pandas as pd

def describe_df(csv):
    """Gets the relative or absolute path of a csv and calls the
        describe function of a dataframe

    Parameters
    ----------
    csv : str
        The relative or absolute path of the csv file

    Returns
    -------
    DataFrame
        A dataframe that contains trivial statistical info of our data 
    """

    df = pd.read_csv(csv)
    df = df.drop(columns=['Unnamed: 0'])    # Drops the index column of our data
    return df.describe()
    

describe_df('../EXCEL_TO_CSV/all_data.csv')
# Out:
# /home/billys/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#         AGIA TRIADA          KIPI  AGIOI THEODOROI     ALOYMINION  \
# count  3.350400e+04  3.350400e+04     33504.000000   33504.000000
# mean   3.783024e+05  2.362162e+05      1277.151730  129539.302991
# std    8.687990e+05  4.088622e+05      2595.674961  196222.712983
# min    0.000000e+00  0.000000e+00        -6.411085       0.000000
# 25%    0.000000e+00  5.443936e+02         1.536073     426.352508
# 50%    1.041660e+03  1.061896e+03         3.944369     433.130626
# 75%    3.655145e+03  3.775184e+05      1355.035002  416679.519994
# max    6.310582e+06  1.206262e+06     11973.571285  863429.099155
#
#        ALOYMINION II  ALOYMINION III        ATHENS  ALEXANDROUPOLIS  \
# count   33504.000000    33504.000000  3.350400e+04     33504.000000
# mean   121679.547964    25258.262596  9.685992e+04      1013.959202
# std    266734.303224    38522.795352  2.300413e+05      1909.862003
# min         0.000000        0.000000  0.000000e+00         0.000000
# 25%         0.000000       88.382746  1.590419e+02         2.669533
# 50%         0.000000       94.061245  4.231297e+02         4.615568
# 75%       789.483771    76947.953124  1.168191e+05      1446.460918
# max    847879.687621   129673.062502  2.279105e+06     25874.792833
#
#        VIPE LARISSA          VOLOS  ...      MOTOR OIL   MOTOR OIL II  \
# count  33504.000000   33504.000000  ...   33504.000000   33504.000000
# mean    1846.558487   20773.619054  ...  113579.480947  140521.482821
# std     3513.097651   39078.208853  ...  173607.696462  280568.706504
# min        0.000000       0.000000  ...       0.000000      -0.002442
# 25%        3.391151      48.056083  ...     219.028360       0.000000
# 50%        8.048931      89.789339  ...     312.346846      29.118020
# 75%     1714.787729   35437.960537  ...  330172.185167     845.733196
# max    17930.389381  261754.931974  ...  538381.818878  845093.522874
#
#              XANTHI       OINOFYTA          PLATY  SALFA ANTHOUSSA  \
# count  33504.000000   33504.000000   33504.000000     33504.000000
# mean    2165.471772   37006.344314    6794.328944      2428.293218
# std     3913.672428   58413.227098   21451.255957      6190.800794
# min        0.000000       0.000000       0.000000         0.000000
# 25%        4.192917     106.600667      11.938141         4.013526
# 50%        8.284445     133.580837      17.900578        10.435777
# 75%     3554.097348   93180.225125    5886.156457      1665.703434
# max    39984.445310  200532.593747  158469.263930     57184.178285
#
#        SALFA ANO LIOSSIA       SERRES      TRIKALA       Weekday
# count       33504.000000  9984.000000  9984.000000  33600.000000
# mean         3363.812846    19.210004     6.309923      2.998571
# std          8305.013580    15.649737     8.620348      2.001457
# min             0.000000     0.000000     0.000000      0.000000
# 25%             6.180076     2.737778     0.000000      1.000000
# 50%            12.487424    14.577779     1.311120      3.000000
# 75%          2389.729019    33.137780    11.046262      5.000000
# max         73844.444072    97.262230    41.778153      6.000000
#
# [8 rows x 44 columns]

# %% [markdown]
# ### Function for getting info of the dataframe

# %%
import pandas as pd

def describe_df(csv):
    """Gets the relative or absolute path of a csv and calls the
        info function of a dataframe

    Parameters
    ----------
    csv : str
        The relative or absolute path of the csv file

    Returns
    -------
    DataFrame
        A dataframe that contains info of our data 
    """

    df = pd.read_csv(csv)
    df = df.drop(columns=['Unnamed: 0'])    # Drops the index column of our data
    return df.info()
    

describe_df('../EXCEL_TO_CSV/all_data.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33600 entries, 0 to 33599
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DateTime                 33600 non-null  object
#  1   AGIA TRIADA              33504 non-null  float64
#  2   SIDIROKASTRO             33504 non-null  object
#  3   KIPI                     33504 non-null  float64
#  4   AGIOI THEODOROI          33504 non-null  float64
#  5   ALOYMINION               33504 non-null  float64
#  6   ALOYMINION II            33504 non-null  float64
#  7   ALOYMINION III           33504 non-null  float64
#  8   ATHENS                   33504 non-null  float64
#  9   ALEXANDROUPOLIS          33504 non-null  float64
#  10  VIPE LARISSA             33504 non-null  float64
#  11  VOLOS                    33504 non-null  float64
#  12  VFL                      33504 non-null  float64
#  13  ALIVERI (PPC)            33504 non-null  float64
#  14  KERATSINI (PPC)          33504 non-null  float64
#  15  KOMOTINI (PPC)           33504 non-null  float64
#  16  LAVRIO (PPC)             33504 non-null  float64
#  17  MEGALOPOLIS
# (PPC)        23520 non-null  float64
#  18  DRAMA                    33480 non-null  float64
#  19  ELPE                     33504 non-null  float64
#  20  ELPE - HAR               23520 non-null  float64
#  21  ENERGIAKI THESS. (ELPE)  33504 non-null  float64
#  22  HERON II                 33504 non-null  float64
#  23  HERONAS                  33504 non-null  float64
#  24  THESSALONIKI             33504 non-null  float64
#  25  THISVI                   33504 non-null  float64
#  26  THRIASIO                 33504 non-null  float64
#  27  KAVALA                   33504 non-null  float64
#  28  KARDITSA                 33504 non-null  float64
#  29  KATERINI                 33504 non-null  float64
#  30  KILKIS                   33504 non-null  float64
#  31  KOKKINA                  33504 non-null  float64
#  32  KOMOTINI                 33504 non-null  float64
#  33  LAMIA                    33504 non-null  float64
#  34  LARISSA                  33504 non-null  float64
#  35  SPATA                    33504 non-null  float64
#  36  MOTOR OIL                33504 non-null  float64
#  37  MOTOR OIL II             33504 non-null  float64
#  38  XANTHI                   33504 non-null  float64
#  39  OINOFYTA                 33504 non-null  float64
#  40  PLATY                    33504 non-null  float64
#  41  SALFA ANTHOUSSA          33504 non-null  float64
#  42  SALFA ANO LIOSSIA        33504 non-null  float64
#  43  SERRES                   9984 non-null   float64
#  44  TRIKALA                  9984 non-null   float64
#  45  Holiday                  33600 non-null  bool
#  46  Weekday                  33600 non-null  int64
# dtypes: bool(1), float64(43), int64(1), object(2)
# memory usage: 11.8+ MB
# /home/billys/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %% [markdown]
# ### Function that returns the sum of null values of the dataset per region

# %%
import pandas as pd

def describe_df(csv):
    """Gets the relative or absolute path of a csv and calls the
        isnull function of a dataframe in order to see how many null values there
        are in the dataset

    Parameters
    ----------
    csv : str
        The relative or absolute path of the csv file

    Returns
    -------
    DataFrame
        A dataframe that contains sum of null values of our data 
    """

    df = pd.read_csv(csv)
    df = df.drop(columns=['Unnamed: 0'])    # Drops the index column of our data
    return df.isnull().sum()
    

describe_df('../EXCEL_TO_CSV/all_data.csv')
# Out:
# DateTime                       0
# AGIA TRIADA                   96
# SIDIROKASTRO                  96
# KIPI                          96
# AGIOI THEODOROI               96
# ALOYMINION                    96
# ALOYMINION II                 96
# ALOYMINION III                96
# ATHENS                        96
# ALEXANDROUPOLIS               96
# VIPE LARISSA                  96
# VOLOS                         96
# VFL                           96
# ALIVERI (PPC)                 96
# KERATSINI (PPC)               96
# KOMOTINI (PPC)                96
# LAVRIO (PPC)                  96
# MEGALOPOLIS\n(PPC)         10080
# DRAMA                        120
# ELPE                          96
# ELPE - HAR                 10080
# ENERGIAKI THESS. (ELPE)       96
# HERON II                      96
# HERONAS                       96
# THESSALONIKI                  96
# THISVI                        96
# THRIASIO                      96
# KAVALA                        96
# KARDITSA                      96
# KATERINI                      96
# KILKIS                        96
# KOKKINA                       96
# KOMOTINI                      96
# LAMIA                         96
# LARISSA                       96
# SPATA                         96
# MOTOR OIL                     96
# MOTOR OIL II                  96
# XANTHI                        96
# OINOFYTA                      96
# PLATY                         96
# SALFA ANTHOUSSA               96
# SALFA ANO LIOSSIA             96
# SERRES                     23616
# TRIKALA                    23616
# Holiday                        0
# Weekday                        0
# dtype: int64

# %% [markdown]
# ### Function for plotting data based on region

# %%
import pandas as pd
import matplotlib.pyplot as plt


def plot_region(csv, region):
    """Gets a csv of data and a wanted region that you want to plot
        from the csv 
    
    Parameters
    ----------
    csv : str
        The absolute or relative path of the csv file

    Returns
    -------
    None
    """
    df = pd.read_csv(csv)
    df.plot(x='DateTime', y=region, kind='line', figsize=(15,10))
    

plot_region('../EXCEL_TO_CSV/all_data.csv', 'TRIKALA')
plot_region('../EXCEL_TO_CSV/all_data.csv', 'SERRES')
plot_region('../EXCEL_TO_CSV/all_data.csv', 'THESSALONIKI')
plot_region('../EXCEL_TO_CSV/all_data.csv', 'KILKIS')
plot_region('../EXCEL_TO_CSV/all_data.csv', 'KATERINI')
