# %% [markdown]
# # Notebook for sending and getting data to and from influxDB

# %%
import pandas as pd

df = pd.read_csv('../EXCEL_TO_CSV/all_data.csv')
df = df.drop(columns=['Unnamed: 0'])    # Drops the index column of our data

print(df)
# Out:
#                   DateTime   AGIA TRIADA SIDIROKASTRO         KIPI  \
# 0      2014-09-01 00:00:00  0.000000e+00      1968.17  1081.714747
# 1      2014-09-01 01:00:00  0.000000e+00       1970.4  1085.089518
# 2      2014-09-01 02:00:00  0.000000e+00       1976.5  1087.033615
# 3      2014-09-01 03:00:00  0.000000e+00      1981.65  1087.900093
# 4      2014-09-01 04:00:00  0.000000e+00      1990.28  1088.613414
# ...                    ...           ...          ...          ...
# 33595  2018-07-31 19:00:00  2.752392e+06  2.86032e+06     0.000000
# 33596  2018-07-31 20:00:00  2.740819e+06   2.8634e+06     0.000000
# 33597  2018-07-31 21:00:00  2.742809e+06  2.87477e+06     0.000000
# 33598  2018-07-31 22:00:00  2.744017e+06  2.89026e+06     0.000000
# 33599  2018-07-31 23:00:00  2.745071e+06  2.93576e+06     0.000000
#
#        AGIOI THEODOROI     ALOYMINION  ALOYMINION II  ALOYMINION III  \
# 0             1.006238     386.378384       0.000000       86.990502
# ...
